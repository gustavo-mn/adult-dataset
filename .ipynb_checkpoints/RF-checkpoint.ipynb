# %% [markdown]
# # Random Forests
#
# Como funciona o random forest ?

# %%
# Processamento dos dados
import numpy  as np
import pandas as pd

# Visualização dos dados
import matplotlib.pyplot as plt
import seaborn           as sns
# %matplotlib inline

# Seleção dos modelos
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import validation_curve
from sklearn.model_selection import ParameterGrid
from sklearn.model_selection import GridSearchCV

# Armazenamento externo de arquivos
from sklearn.externals import joblib

# Métricas de avaliação
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import accuracy_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report

# %%
# Função para exibir e salvar os resultados do classificador final

def exibir_resultados_finais(clf, 
                             test_data, 
                             test_target, 
                             id_abordagem, 
                             str_balanceamento, 
                             path_arquivos,
                             tipo_classificador,
                             fracao_dataset=0.1,
                             salvar_resultados=False):
    
    # Classificando o conjunto de teste

    predicoes = clf.predict(test_data)

    if tipo_classificador == 'arvore':
    
        # Salvando a árvore treinada graficamente

        export_graphviz(clf, 
                        out_file=path_arquivos+tipo_classificador+'-final-abordagem-'+str(id_abordagem)+'-'+str_balanceamento+'-dataset-'+str(int(fracao_dataset*100))+'pct.dot', 
                        feature_names=test_data.columns,  
                        class_names=['Less than or equal to', 'More than'],  
                        filled=True, rounded=True,  
                        special_characters=True)  

    # Avaliando o desempenho

    # Matriz de confusão

    cfs_mtx = confusion_matrix(test_target, predicoes)
    plt.figure(figsize=(20,10))
    sns.set(font_scale=2)
    ax = sns.heatmap(cfs_mtx, 
                     xticklabels=['$\leq50$K', '$>50$K'], 
                     yticklabels=['$\leq50$K', '$>50$K'], 
                     annot=cfs_mtx,
                     fmt='d',
                     cbar=None)

    ax.set_xlabel('Predito', labelpad=20, fontsize=30)
    ax.set_ylabel('Real', labelpad=20, fontsize=30)
    ax.set_title('Matriz de Confusão')
    
    acc = accuracy_score(test_target, predicoes)
    pre = precision_score(test_target, predicoes)
    rec = recall_score(test_target, predicoes)
    f1 = f1_score(test_target, predicoes)
    
    if tipo_classificador in ['svm-rbf','svm-linear']:
        predicoes = clf.decision_function(test_data)
    elif tipo_classificador in ['arvore','naive-bayes','logit','knn','rf']:
        predicoes = clf.predict_proba(test_data)[:,1]
    
    roc_auc = roc_auc_score(test_target, predicoes)
    prc_auc = average_precision_score(test_target, predicoes)

    print('Acurácia: %.3f %%' % (acc*100))
    print('Precisão: %.3f %%' % (pre*100))
    print('Recall: %.3f %%' % (rec*100))
    print('F1 score: %3f %%' % (f1*100))
    print('ROC AUC: %.3f %%' % (roc_auc*100))
    print('PRC AUC: %.3f %%' % (prc_auc*100))

    # plot_confusion_matrix(cfs_mtx, ['<=50K', '>50K'], normalize=False)
    
    if salvar_resultados:
        if tipo_classificador == 'arvore':
            path_graficos = 'Classificadores/Arvores-decisao/'
        elif tipo_classificador in ['svm-linear', 'svm-rbf']:
            path_graficos = 'Classificadores/SVM/'
        elif tipo_classificador == 'naive-bayes':
            path_graficos = 'Classificadores/Naive-bayes/'
        elif tipo_classificador == 'logit':
            path_graficos = 'Classificadores/Regressao-logistica/'
        elif tipo_classificador == 'knn':
            path_graficos = 'Classificadores/kNN/'
        elif tipo_classificador == 'rf':
            path_graficos = 'Classificadores/Random-forest/'
        elif tipo_classificador == 'mlp':
            path_graficos = 'Classificadores/Redes-neurais-MLP-2/'
        
        joblib.dump(predicoes,
                    path_arquivos+tipo_classificador+'-final-abordagem-'+str(id_abordagem)+'-'+str_balanceamento+'-predicoes.pkl')    
        
        filename = path_graficos+tipo_classificador+'-final-abordagem-'+str(id_abordagem)+'-'+str_balanceamento+'-matriz-confusao.png'
        plt.savefig(filename)
        
        d = {'Acuracia': acc, 
             'Precisao': pre, 
             'Recall': rec, 
             'F1': f1,
             'ROC AUC': roc_auc, 
             'PRC AUC': prc_auc}
        
        temp = pd.Series(data=d).to_csv(path=path_arquivos+tipo_classificador+'-final-abordagem-'+str(id_abordagem)+'-'+str_balanceamento+'-medidas.csv', sep=',')
        
        
    plt.show()
    
fracao_dataset=0.1

# %% [markdown]
# ## Carregamento dos datasets balanceados

# %%
# Conjuntos de treinamento
# Conjunto 1
conjunto1_train        = pd.read_csv('Data/datasets-balanceados/train_data_b_1.csv')
conjunto1_train_target = pd.read_csv('Data/datasets-balanceados/train_target_b_1.csv')

# Conjunto 2
conjunto2_train        = pd.read_csv('Data/datasets-balanceados/train_data_b_2.csv')
conjunto2_train_target = pd.read_csv('Data/datasets-balanceados/train_target_b_2.csv')

# Conjunto 3
conjunto3_train        = pd.read_csv('Data/datasets-balanceados/train_data_b_3.csv')
conjunto3_train_target = pd.read_csv('Data/datasets-balanceados/train_target_b_3.csv')

# Conjunto 4
conjunto4_train        = pd.read_csv('Data/datasets-balanceados/train_data_b_4.csv')
conjunto4_train_target = pd.read_csv('Data/datasets-balanceados/train_target_b_4.csv')

# %%
# Conjuntos de teste
# Conjunto 1
conjunto1_test        = pd.read_csv('Data/datasets-balanceados/test_data_b_1.csv')
conjunto1_test_target = pd.read_csv('Data/datasets-balanceados/test_target_b_1.csv')

# Conjunto 2
conjunto2_test        = pd.read_csv('Data/datasets-balanceados/test_data_b_2.csv')
conjunto2_test_target = pd.read_csv('Data/datasets-balanceados/test_target_b_2.csv')

# Conjunto 3
conjunto3_test        = pd.read_csv('Data/datasets-balanceados/test_data_b_3.csv')
conjunto3_test_target = pd.read_csv('Data/datasets-balanceados/test_target_b_3.csv')

# Conjunto 4
conjunto4_test        = pd.read_csv('Data/datasets-balanceados/test_data_b_4.csv')
conjunto4_test_target = pd.read_csv('Data/datasets-balanceados/test_target_b_4.csv')

# %% [markdown]
# ## Carregamento dos datasets desbalanceados

# %%
# Leitura dos Datasets desbalanceados

# Conjuntos de treinamento

# Conjunto 1
conjunto1_train_desbalanceado        = pd.read_csv('Data/datasets-desbalanceados/train_data_1.csv')
conjunto1_train_target_desbalanceado = pd.read_csv('Data/datasets-desbalanceados/train_target_1.csv')

# Conjunto 2
conjunto2_train_desbalanceado        = pd.read_csv('Data/datasets-desbalanceados/train_data_2.csv')
conjunto2_train_target_desbalanceado = pd.read_csv('Data/datasets-desbalanceados/train_target_2.csv')

# Conjunto 3
conjunto3_train_desbalanceado        = pd.read_csv('Data/datasets-desbalanceados/train_data_3.csv')
conjunto3_train_target_desbalanceado = pd.read_csv('Data/datasets-desbalanceados/train_target_3.csv')

# Conjunto 4
conjunto4_train_desbalanceado        = pd.read_csv('Data/datasets-desbalanceados/train_data_4.csv')
conjunto4_train_target_desbalanceado = pd.read_csv('Data/datasets-desbalanceados/train_target_4.csv')

# %%
# Conjuntos de teste
# Conjunto 1
conjunto1_test_desbalanceado        = pd.read_csv('Data/datasets-desbalanceados/test_data_1.csv')
conjunto1_test_target_desbalanceado = pd.read_csv('Data/datasets-desbalanceados/test_target_1.csv')

# Conjunto 2
conjunto2_test_desbalanceado        = pd.read_csv('Data/datasets-desbalanceados/test_data_2.csv')
conjunto2_test_target_desbalanceado = pd.read_csv('Data/datasets-desbalanceados/test_target_2.csv')

# Conjunto 3
conjunto3_test_desbalanceado        = pd.read_csv('Data/datasets-desbalanceados/test_data_3.csv')
conjunto3_test_target_desbalanceado = pd.read_csv('Data/datasets-desbalanceados/test_target_3.csv')

# Conjunto 4
conjunto4_test_desbalanceado        = pd.read_csv('Data/datasets-desbalanceados/test_data_4.csv')
conjunto4_test_target_desbalanceado = pd.read_csv('Data/datasets-desbalanceados/test_target_4.csv')

# %% [markdown]
# ## Pré-processamento dos dados

# %% [markdown]
# ### Remoção de colunas inúteis

# %%
# Lista de csvs
df_data_balanceado        = [conjunto1_train, conjunto2_train ,conjunto3_train ,conjunto4_train,
                               conjunto1_test, conjunto2_test  ,conjunto3_test  ,conjunto4_test]

df_target_balanceado      = [conjunto1_train_target, conjunto2_train_target, conjunto3_train_target, conjunto4_train_target,
                              conjunto1_test_target, conjunto2_test_target , conjunto3_test_target , conjunto4_test_target]

df_data_desbalanceado     = [conjunto1_train_desbalanceado, conjunto2_train_desbalanceado, conjunto3_train_desbalanceado, conjunto4_train_desbalanceado,
                              conjunto1_test_desbalanceado,  conjunto2_test_desbalanceado,  conjunto3_test_desbalanceado, conjunto4_test_desbalanceado]

df_target_desbalanceado   = [conjunto1_train_target_desbalanceado, conjunto2_train_target_desbalanceado, conjunto3_train_target_desbalanceado, conjunto4_train_target_desbalanceado,
                              conjunto1_test_target_desbalanceado,  conjunto2_test_target_desbalanceado,  conjunto3_test_target_desbalanceado, conjunto4_test_target_desbalanceado]

# %%
# Remoção das colunas ids
for df_index in range(0,8):
    # Dataset balanceado
    df_data_balanceado[df_index].drop('id',axis=1,inplace=True)
    df_target_balanceado[df_index].drop('id',axis=1,inplace=True)
    
    # Dataset desbalanceado
    df_data_desbalanceado[df_index].drop('id',axis=1,inplace=True)
    df_target_desbalanceado[df_index].drop('id',axis=1,inplace=True)

# %%
# Transformação das features categóricas em dummy variables, utilizando get_dummies

def get_dummies_features(df):
    ''' Função utilizada para a codificação de features categóricas de um dataframe em features binárias'''
    output = pd.DataFrame(index = df.index)

    # Verifica cada feature, transformando somente as features categóricas/object
    for col, col_data in df.iteritems():

        if col_data.dtype == object:
            col_data = pd.get_dummies(col_data, prefix = col)  
        
        output = output.join(col_data)
    
    return output

# %%
# Convertendo as features presentes no dataframes em dummies :

# Datasets balanceados
# Conjunto de treinamento
conjunto1_train = get_dummies_features(conjunto1_train)
conjunto2_train = get_dummies_features(conjunto2_train)
conjunto3_train = get_dummies_features(conjunto3_train)
conjunto4_train = get_dummies_features(conjunto4_train)

# Conjunto de teste
conjunto1_test = get_dummies_features(conjunto1_test)
conjunto2_test = get_dummies_features(conjunto2_test) 
conjunto3_test = get_dummies_features(conjunto3_test)
conjunto4_test = get_dummies_features(conjunto4_test)

# Datasets desbalanceados
conjunto1_train_desbalanceado = get_dummies_features(conjunto1_train_desbalanceado)
conjunto2_train_desbalanceado = get_dummies_features(conjunto2_train_desbalanceado)
conjunto3_train_desbalanceado = get_dummies_features(conjunto3_train_desbalanceado)
conjunto4_train_desbalanceado = get_dummies_features(conjunto4_train_desbalanceado)

# Conjunto de teste
conjunto1_test_desbalanceado = get_dummies_features(conjunto1_test_desbalanceado)
conjunto2_test_desbalanceado = get_dummies_features(conjunto2_test_desbalanceado) 
conjunto3_test_desbalanceado = get_dummies_features(conjunto3_test_desbalanceado)
conjunto4_test_desbalanceado = get_dummies_features(conjunto4_test_desbalanceado)

# %% [markdown]
# ## Treinamento
#
# - 4 Cenários são testados:
#     - Dataset 1 - sem dados faltantes, com a presença de outliers
#     - Dataset 2 - imputação de dados faltantes de acordo com a moda, com a presença de outliers
#     - Dataset 3 - imputação de dados faltantes de acordo com a moda, sem a presença de outliers
#     - Dataset 4 - sem dados faltantes, sem a presença de outliers
#
#
# - Métrica utilizada para os datasets balanceados: acurácia
# - Métrica utilizada para os datasets desbalanceados: F-Score e ROC AUC
#
# <div align="center">
# No algoritmo k-NN, temos como hiperparâmetro a quantidade k de vizinhos próximos que serão utilizados para a classificação das instâncias do dataset. Primeiramente, devemos realizar uma busca pelo melhor parâmetro, e após esse processo, realizar o treinamento do modelo para o valor k ótimo. Abaixo, os 4 cenários são verificados.
# </div>

# %%
# importanto o classificador
from sklearn.ensemble import RandomForestClassifier as RF
clf_rf = RF(max_depth=6)

# %% [markdown]
# ### Cenários para os datasets balanceados

# %%
# Teste base: Verificando o funcionamento correto do modelo para as configurações padrões: K = 5
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)
prediction_conjunto1 = clf_rf.predict(conjunto1_test)
print('Acurácia para o conjunto 1: {:.2f}'.format(accuracy_score(conjunto1_test_target.earnings,prediction_conjunto1,normalize=True)))

clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)
prediction_conjunto2 = clf_rf.predict(conjunto2_test)
print('Acurácia para o conjunto 2: {:.2f}'.format(accuracy_score(conjunto2_test_target.earnings,prediction_conjunto2,normalize=True)))

clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)
prediction_conjunto3 = clf_rf.predict(conjunto3_test)
print('Acurácia para o conjunto 3: {:.2f}'.format(accuracy_score(conjunto3_test_target.earnings,prediction_conjunto3,normalize=True)))

clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)
prediction_conjunto4 = clf_rf.predict(conjunto4_test)
print('Acurácia para o conjunto 4: {:.2f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_conjunto4,normalize=True)))
# Out:
# Acurácia para o conjunto 1: 0.82
# Acurácia para o conjunto 2: 0.83
# Acurácia para o conjunto 3: 0.83
# Acurácia para o conjunto 4: 0.80

# %%
def validation_graph_acc(model,X,y,hyperparameter,grid_search,k_folds,score,jobs=1):
    ''' Cria a curva de validação, para busca do hiperparâmetro ótimo'''

    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    scores_treino, scores_validacao = validation_curve(model,
                                                       X=X,
                                                       y=y,
                                                       param_name=hyperparameter,
                                                       param_range=grid_search,
                                                       cv=k_folds,
                                                       scoring=score,
                                                       n_jobs=jobs)
    
    # Estatísticas do treino
    train_scores_mean = np.mean(scores_treino   , axis=1)
    train_scores_std  = np.std (scores_treino   , axis=1)
    test_scores_mean  = np.mean(scores_validacao, axis=1)
    test_scores_std   = np.std (scores_validacao, axis=1)

    # Estilo do sns
    sns.set_style('whitegrid')

    # Parâmetros
    param_range = grid_search
    lw = 2

    # Ajuste dos subplots
    plt.figure(figsize=(30,8))
    plt.title('Acurácia para n árvores',fontsize=20)
    plt.xlabel('Quantidade de árvores',fontsize=20)
    plt.ylabel('Acurácia',fontsize=20)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.grid(True)

    plt.plot(param_range, train_scores_mean, label="Acurácia no treinamento",color="darkorange", lw=lw)
    plt.fill_between(param_range, (train_scores_mean - train_scores_std),(train_scores_mean + train_scores_std), alpha=0.2,color="darkorange", lw=lw)
    plt.plot(param_range, test_scores_mean, label="Acurácia na validação cruzada",color="navy", lw=lw)
    plt.fill_between(param_range, (test_scores_mean - test_scores_std),(test_scores_mean + test_scores_std), alpha=0.2,color="navy", lw=lw)
    plt.legend(loc="best",fontsize='xx-large')
    plt.show()

# %%
def validation_graph_roc(model,X,y,hyperparameter,grid_search,k_folds,score,jobs=1):
    ''' Cria a curva de validação, para busca do hiperparâmetro ótimo'''

    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    scores_treino, scores_validacao = validation_curve(model,
                                                       X=X,
                                                       y=y,
                                                       param_name=hyperparameter,
                                                       param_range=grid_search,
                                                       cv=k_folds,
                                                       scoring=score,
                                                       n_jobs=jobs)
    
    # Estatísticas do treino
    train_scores_mean = np.mean(scores_treino   , axis=1)
    train_scores_std  = np.std (scores_treino   , axis=1)
    test_scores_mean  = np.mean(scores_validacao, axis=1)
    test_scores_std   = np.std (scores_validacao, axis=1)

    # Estilo do sns
    sns.set_style('whitegrid')

    # Parâmetros
    param_range = grid_search
    lw = 2

    # Ajuste dos subplots
    plt.figure(figsize=(30,8))
    plt.title('ROC AUC para n árvores ',fontsize=20)
    plt.xlabel('Quantidade de árvores',fontsize=20)
    plt.ylabel('ROC AUC',fontsize=20)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.grid(True)

    plt.plot(param_range, train_scores_mean, label="ROC AUC no treinamento",color="darkorange", lw=lw)
    plt.fill_between(param_range, (train_scores_mean - train_scores_std),(train_scores_mean + train_scores_std), alpha=0.2,color="darkorange", lw=lw)
    plt.plot(param_range, test_scores_mean, label="ROC AUC na validação cruzada",color="navy", lw=lw)
    plt.fill_between(param_range, (test_scores_mean - test_scores_std),(test_scores_mean + test_scores_std), alpha=0.2,color="navy", lw=lw)
    plt.legend(loc="best",fontsize='xx-large')
    plt.show()

# %%
def validation_graph_f1(model,X,y,hyperparameter,grid_search,k_folds,score,jobs=1):
    ''' Cria a curva de validação, para busca do hiperparâmetro ótimo'''

    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    scores_treino, scores_validacao = validation_curve(model,
                                                       X=X,
                                                       y=y,
                                                       param_name=hyperparameter,
                                                       param_range=grid_search,
                                                       cv=k_folds,
                                                       scoring=score,
                                                       n_jobs=jobs)
    
    # Estatísticas do treino
    train_scores_mean = np.mean(scores_treino   , axis=1)
    train_scores_std  = np.std (scores_treino   , axis=1)
    test_scores_mean  = np.mean(scores_validacao, axis=1)
    test_scores_std   = np.std (scores_validacao, axis=1)

    # Estilo do sns
    sns.set_style('whitegrid')

    # Parâmetros
    param_range = grid_search
    lw = 2

    # Ajuste dos subplots
    plt.figure(figsize=(30,8))
    plt.title('F1-score para n árvores ',fontsize=20)
    plt.xlabel('Quantidade de árvores',fontsize=20)
    plt.ylabel('F1-score',fontsize=20)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.grid(True)

    plt.plot(param_range, train_scores_mean, label="Score F1 no treinamento",color="darkorange", lw=lw)
    plt.fill_between(param_range, (train_scores_mean - train_scores_std),(train_scores_mean + train_scores_std), alpha=0.2,color="darkorange", lw=lw)
    plt.plot(param_range, test_scores_mean, label="Score F1 na validação cruzada",color="navy", lw=lw)
    plt.fill_between(param_range, (test_scores_mean - test_scores_std),(test_scores_mean + test_scores_std), alpha=0.2,color="navy", lw=lw)
    plt.legend(loc="best",fontsize='xx-large')
    plt.show()

# %% [markdown]
# ### Dataset 1

# %% [markdown]
# #### Acurácia

# %%
# Busca do melhor hiperparâmetro
validation_graph_acc(model=RF(max_depth=25),X=conjunto1_train,y=conjunto1_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='accuracy',jobs=-1)

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_1 = cross_val_score(RF(n_estimators=10),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_1)
print(np.mean(cross_val_bal_1))
# Out:
# [ 0.88528139  0.88744589  0.8982684   0.85497835  0.89177489  0.87878788
#   0.88744589  0.87229437  0.87445887  0.87012987]
# 0.880086580087

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_1 = cross_val_score(RF(n_estimators=15),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_1)
print(np.mean(cross_val_bal_1))
# Out:
# [ 0.89393939  0.87229437  0.8982684   0.87229437  0.8982684   0.88311688
#   0.88744589  0.87229437  0.86580087  0.87229437]
# 0.881601731602

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_1 = cross_val_score(RF(n_estimators=20),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_1)
print(np.mean(cross_val_bal_1))
# Out:
# [ 0.88744589  0.89177489  0.89393939  0.89393939  0.89177489  0.8961039
#   0.87662338  0.87662338  0.88095238  0.87445887]
# 0.886363636364

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_1 = cross_val_score(RF(n_estimators=25),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_1)
print(np.mean(cross_val_bal_1))
# Out:
# [ 0.89177489  0.88528139  0.87878788  0.87878788  0.89177489  0.9004329
#   0.8982684   0.87229437  0.88095238  0.85714286]
# 0.88354978355

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=10)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(accuracy_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(accuracy_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.811
# F1 para o conjunto 1: 0.823

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(accuracy_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(accuracy_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.818
# F1 para o conjunto 1: 0.824

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=20)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(accuracy_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(accuracy_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.807
# F1 para o conjunto 1: 0.826

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(accuracy_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(accuracy_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.831
# F1 para o conjunto 1: 0.833

# %% [markdown]
# #### F1-Score

# %%
# Busca do melhor hiperparâmetro
validation_graph_f1(model=RF(max_depth=25),X=conjunto1_train,y=conjunto1_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='f1',jobs=-1)

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_f1_1 = cross_val_score(RF(n_estimators=5),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_1)
print(np.mean(cross_val_bal_f1_1))
# Out:
# [ 0.88655462  0.8625      0.88841202  0.85947047  0.88695652  0.87012987
#   0.87846482  0.85531915  0.86324786  0.86315789]
# 0.8714213225

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_f1_1 = cross_val_score(RF(n_estimators=10),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_1)
print(np.mean(cross_val_bal_f1_1))
# Out:
# [ 0.89699571  0.86847599  0.89804772  0.88185654  0.87391304  0.89333333
#   0.87445887  0.87772926  0.87610619  0.86680761]
# 0.880772427683

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_f1_1 = cross_val_score(RF(n_estimators=15),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_1)
print(np.mean(cross_val_bal_f1_1))
# Out:
# [ 0.89217759  0.89292929  0.89451477  0.87083333  0.91101695  0.89324619
#   0.89915966  0.88272921  0.88655462  0.88198758]
# 0.8905149195

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_f1_1 = cross_val_score(RF(n_estimators=20),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_1)
print(np.mean(cross_val_bal_f1_1))
# Out:
# [ 0.8993576   0.88016529  0.90393013  0.88469602  0.88747346  0.88453159
#   0.88842105  0.88602151  0.9         0.88655462]
# 0.890115126974

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_f1_1 = cross_val_score(RF(n_estimators=25),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_1)
print(np.mean(cross_val_bal_f1_1))
# Out:
# [ 0.89308176  0.88343558  0.90086207  0.87866109  0.90021231  0.8993576
#   0.89121339  0.87553648  0.88050314  0.87190083]
# 0.887476425751

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_f1_1 = cross_val_score(RF(n_estimators=30),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_1)
print(np.mean(cross_val_bal_f1_1))
# Out:
# [ 0.89263158  0.89117043  0.8993576   0.88612836  0.90212766  0.88453159
#   0.8974359   0.88222698  0.88421053  0.87784679]
# 0.889766742162

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.798
# F1 para o conjunto 1: 0.650

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.820
# F1 para o conjunto 1: 0.669

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=20)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.806
# F1 para o conjunto 1: 0.642

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.813
# F1 para o conjunto 1: 0.654

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=30)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.802
# F1 para o conjunto 1: 0.651

# %% [markdown]
# #### ROC AUC

# %%
# Busca do melhor hiperparâmetro
validation_graph_roc(model=RF(max_depth=25),X=conjunto1_train,y=conjunto1_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='roc_auc',jobs=-1)

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_roc_1 = cross_val_score(RF(n_estimators=5),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_1)
print(np.mean(cross_val_bal_roc_1))
# Out:
# [ 0.92883379  0.91399149  0.9410993   0.91168644  0.93257248  0.93921591
#   0.93557092  0.93182287  0.92721276  0.91196754]
# 0.927397350125

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_roc_1 = cross_val_score(RF(n_estimators=10),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_1)
print(np.mean(cross_val_bal_roc_1))
# Out:
# [ 0.9357677   0.95174378  0.95373025  0.93539289  0.95712224  0.95211859
#   0.93657353  0.94498791  0.94196136  0.9360488 ]
# 0.944544704934

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_roc_1 = cross_val_score(RF(n_estimators=15),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_1)
print(np.mean(cross_val_bal_roc_1))
# Out:
# [ 0.95444238  0.95326175  0.95741272  0.93239445  0.96161991  0.96107644
#   0.94247672  0.94932629  0.94130545  0.94881093]
# 0.950212702161

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_roc_1 = cross_val_score(RF(n_estimators=20),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_1)
print(np.mean(cross_val_bal_roc_1))
# Out:
# [ 0.95718783  0.9558479   0.96350331  0.94916699  0.96442158  0.96065479
#   0.9551264   0.94776147  0.9491014   0.95105976]
# 0.955383144994

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_roc_1 = cross_val_score(RF(n_estimators=25),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_1)
print(np.mean(cross_val_bal_roc_1))
# Out:
# [ 0.95204363  0.95673807  0.96200409  0.94778021  0.95785311  0.96624876
#   0.95818107  0.95097543  0.95353348  0.95126591]
# 0.955662375143

# %%
# Busca do melhor parâmetro utilizando gridSearchCV
cross_val_bal_roc_1 = cross_val_score(RF(n_estimators=30),conjunto1_train,conjunto1_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_1)
print(np.mean(cross_val_bal_roc_1))
# Out:
# [ 0.95656003  0.95537003  0.96158243  0.9476584   0.96216338  0.96044864
#   0.95622271  0.95090047  0.95544499  0.94776147]
# 0.955411255411

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.811
# F1 para o conjunto 1: 0.823

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=10)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.811
# F1 para o conjunto 1: 0.823

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.811
# F1 para o conjunto 1: 0.823

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=20)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.811
# F1 para o conjunto 1: 0.823

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.811
# F1 para o conjunto 1: 0.823

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=30)
clf_rf.fit(conjunto1_train,conjunto1_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1 para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1 para o conjunto 1: 0.811
# F1 para o conjunto 1: 0.823

# %% [markdown]
# ### Dataset 2

# %%
# Busca do melhor hiperparâmetro
validation_graph_acc(model=RF(max_depth=8),X=conjunto2_train,y=conjunto2_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='accuracy',jobs=-1)

# %%
# acurácia no conjunto de treinamento
cross_val_bal_2 = cross_val_score(RF(n_estimators=5),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_2)
print(np.mean(cross_val_bal_2))
# Out:
# [0.8484252  0.86561265 0.86561265 0.87549407 0.87747036 0.86363636
#  0.86758893 0.88537549 0.89130435 0.87944664]
# 0.8719966698826678

# %%
# acurácia no conjunto de treinamento
cross_val_bal_2 = cross_val_score(RF(n_estimators=10),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_2)
print(np.mean(cross_val_bal_2))
# Out:
# [0.87598425 0.90316206 0.88339921 0.88537549 0.86758893 0.86561265
#  0.88735178 0.8715415  0.88735178 0.87944664]
# 0.8806814291494195

# %%
# acurácia no conjunto de treinamento
cross_val_bal_2 = cross_val_score(RF(n_estimators=15),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_2)
print(np.mean(cross_val_bal_2))
# Out:
# [0.87992126 0.88537549 0.88339921 0.88735178 0.87944664 0.87549407
#  0.90316206 0.90118577 0.89525692 0.8972332 ]
# 0.8887826398182442

# %%
# acurácia no conjunto de treinamento
cross_val_bal_2 = cross_val_score(RF(n_estimators=20),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_2)
print(np.mean(cross_val_bal_2))
# Out:
# [0.88779528 0.89525692 0.88339921 0.89525692 0.88537549 0.87944664
#  0.90513834 0.88735178 0.90513834 0.89328063]
# 0.8917439544365255

# %%
# acurácia no conjunto de treinamento
cross_val_bal_2 = cross_val_score(RF(n_estimators=25),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_2)
print(np.mean(cross_val_bal_2))
# Out:
# [0.88976378 0.88142292 0.89525692 0.90316206 0.8715415  0.88735178
#  0.90513834 0.88735178 0.90909091 0.89920949]
# 0.8929289471227163

# %%
# acurácia no conjunto de treinamento
cross_val_bal_2 = cross_val_score(RF(n_estimators=30),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_2)
print(np.mean(cross_val_bal_2))
# Out:
# [0.89566929 0.89525692 0.88537549 0.90118577 0.87747036 0.88142292
#  0.90316206 0.88735178 0.91699605 0.90316206]
# 0.894705269054807

# %%
# acurácia no conjunto de treinamento
cross_val_bal_2 = cross_val_score(RF(n_estimators=35),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_2)
print(np.mean(cross_val_bal_2))
# Out:
# [0.8976378  0.8972332  0.89920949 0.89920949 0.87747036 0.87944664
#  0.91304348 0.89328063 0.90711462 0.89525692]
# 0.8958902617409977

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 2: 0.792
# Acurácia para o conjunto 2: 0.814

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=10)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 2: 0.790
# Acurácia para o conjunto 2: 0.828

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 2: 0.797
# Acurácia para o conjunto 2: 0.824

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=20)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 2: 0.785
# Acurácia para o conjunto 2: 0.822

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 2: 0.796
# Acurácia para o conjunto 2: 0.826

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=30)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 2: {:.3f}'.format(accuracy_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 2: 0.786
# Acurácia para o conjunto 2: 0.819

# %% [markdown]
# #### F1-Score

# %%
# Busca do melhor hiperparâmetro
validation_graph_f1(model=RF(max_depth=8),X=conjunto2_train,y=conjunto2_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='f1',jobs=-1)

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_2 = cross_val_score(RF(n_estimators=5),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_2)
print(np.mean(cross_val_bal_f1_2))
# Out:
# [0.88030888 0.87719298 0.86538462 0.87666034 0.86756238 0.85546875
#  0.87548638 0.87692308 0.88549618 0.875     ]
# 0.8735483591196143

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_2 = cross_val_score(RF(n_estimators=10),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_2)
print(np.mean(cross_val_bal_f1_2))
# Out:
# [0.8972332  0.87843137 0.88047809 0.89494163 0.86549708 0.88933602
#  0.89278752 0.88372093 0.89940828 0.88163265]
# 0.8863466779824589

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_2 = cross_val_score(RF(n_estimators=15),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_2)
print(np.mean(cross_val_bal_f1_2))
# Out:
# [0.89402697 0.88631985 0.87452471 0.88636364 0.86956522 0.88627451
#  0.90421456 0.88931298 0.91603053 0.89534884]
# 0.8901981807243666

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_2 = cross_val_score(RF(n_estimators=20),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_2)
print(np.mean(cross_val_bal_f1_2))
# Out:
# [0.88932806 0.89411765 0.88888889 0.89748549 0.87121212 0.88062622
#  0.89320388 0.8957529  0.91650485 0.88492063]
# 0.8912040705260699

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_2 = cross_val_score(RF(n_estimators=25),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_2)
print(np.mean(cross_val_bal_f1_2))
# Out:
# [0.89370079 0.88888889 0.88201161 0.90018832 0.87758945 0.87109375
#  0.90630975 0.89922481 0.93005671 0.88888889]
# 0.8937952966783623

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_2 = cross_val_score(RF(n_estimators=30),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_2)
print(np.mean(cross_val_bal_2))
# Out:
# [0.89534884 0.8815534  0.89668616 0.89483748 0.88291747 0.88062622
#  0.90661479 0.91050584 0.91923077 0.90118577]
# 0.8958902617409977

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.756
# F1-Score para o conjunto 2: 0.634

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=10)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.760
# F1-Score para o conjunto 2: 0.651

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.788
# F1-Score para o conjunto 2: 0.645

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=20)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.780
# F1-Score para o conjunto 2: 0.660

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.783
# F1-Score para o conjunto 2: 0.651

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=30)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.776
# F1-Score para o conjunto 2: 0.656

# %% [markdown]
# #### ROC AUC

# %%
# Busca do melhor hiperparâmetro
validation_graph_roc(model=RF(max_depth=8),X=conjunto2_train,y=conjunto2_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='roc_auc',jobs=-1)

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_2 = cross_val_score(RF(n_estimators=5),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_2)
print(np.mean(cross_val_bal_roc_2))
# Out:
# [0.92950586 0.93384524 0.91711322 0.9335406  0.92747114 0.91606649
#  0.9376572  0.93050977 0.95106157 0.94775735]
# 0.9324528433962115

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_2 = cross_val_score(RF(n_estimators=10),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_2)
print(np.mean(cross_val_bal_roc_2))
# Out:
# [0.9508029  0.94639035 0.93987564 0.94128951 0.94905404 0.93260323
#  0.94940555 0.9350482  0.96086488 0.95481104]
# 0.9460145337825709

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_2 = cross_val_score(RF(n_estimators=15),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_2)
print(np.mean(cross_val_bal_roc_2))
# Out:
# [0.95023715 0.95367839 0.95160837 0.94410161 0.94853068 0.93559499
#  0.95871674 0.94511709 0.9763627  0.96243497]
# 0.9526382692507454

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_2 = cross_val_score(RF(n_estimators=20),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_2)
print(np.mean(cross_val_bal_roc_2))
# Out:
# [0.95236065 0.94928838 0.9513584  0.94603103 0.94664032 0.94548423
#  0.94989767 0.9533425  0.97200394 0.95510006]
# 0.9521507180991053

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_2 = cross_val_score(RF(n_estimators=25),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_2)
print(np.mean(cross_val_bal_roc_2))
# Out:
# [0.95398816 0.95038198 0.96181006 0.95535784 0.95478761 0.94364074
#  0.96181006 0.95006952 0.97495665 0.96434095]
# 0.957114355799819

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_2 = cross_val_score(RF(n_estimators=30),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_2)
print(np.mean(cross_val_bal_roc_2))
# Out:
# [0.95317441 0.95298317 0.95447515 0.95062413 0.95641238 0.94693715
#  0.96131013 0.95667797 0.97326938 0.96524707]
# 0.957111094652285

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_2 = cross_val_score(RF(n_estimators=35),conjunto2_train,conjunto2_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_2)
print(np.mean(cross_val_bal_roc_2))
# Out:
# [0.95571641 0.95550626 0.95515474 0.95148339 0.95584996 0.94049274
#  0.96218501 0.9538893  0.97758128 0.96483307]
# 0.9572692149219696

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.865
# ROC AUC para o conjunto 2: 0.844

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=10)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.887
# ROC AUC para o conjunto 2: 0.860

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.895
# ROC AUC para o conjunto 2: 0.870

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=20)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.898
# ROC AUC para o conjunto 2: 0.877

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.898
# ROC AUC para o conjunto 2: 0.876

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=30)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.901
# ROC AUC para o conjunto 2: 0.882

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.901
# ROC AUC para o conjunto 2: 0.878

# %%
path_arquivos = 'Classificadores/Random-forest/'

clf_rf = RF(max_depth=8, n_estimators=20)
clf_rf.fit(conjunto2_train,conjunto2_train_target.earnings)
joblib.dump(clf_rf, 
            path_arquivos+'rf-final-abordagem-2-balanceado-dataset-'+str(int(fracao_dataset*100))+'pct.pkl')

path_arquivos = 'Classificadores/Random-forest/'

clf_final_balanceado = joblib.load(path_arquivos+'rf-final-abordagem-2-balanceado-dataset-'+str(int(fracao_dataset*100))+'pct.pkl')

exibir_resultados_finais(clf=clf_final_balanceado, 
                         test_data=conjunto2_test_desbalanceado, 
                         test_target=conjunto2_test_target_desbalanceado.earnings, 
                         id_abordagem=2, 
                         str_balanceamento='balanceado', 
                         fracao_dataset=0.1,
                         path_arquivos=path_arquivos,
                         tipo_classificador='rf',
                         salvar_resultados=True)
# Out:
# Acurácia: 79.653 %
# Precisão: 54.934 %
# Recall: 86.082 %
# F1 score: 67.068273 %
# ROC AUC: 89.485 %
# PRC AUC: 72.892 %

# %% [markdown]
# ### Dataset 3

# %%
# Busca do melhor hiperparâmetro
validation_graph_acc(model=RF(max_depth=25),X=conjunto3_train,y=conjunto3_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='accuracy',jobs=-1)

# %%
# acurácia no conjunto de teste
cross_val_bal_3 = cross_val_score(RF(n_estimators=15),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_3)
print(np.mean(cross_val_bal_3))
# Out:
# [ 0.87117904  0.87554585  0.87280702  0.87719298  0.86842105  0.87061404
#   0.88815789  0.86842105  0.91447368  0.90131579]
# 0.88081283996

# %%
# acurácia no conjunto de teste
cross_val_bal_3 = cross_val_score(RF(n_estimators=25),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_3)
print(np.mean(cross_val_bal_3))
# Out:
# [ 0.88209607  0.89737991  0.85526316  0.875       0.88377193  0.87938596
#   0.88377193  0.86184211  0.90570175  0.90350877]
# 0.882772159657

# %%
# acurácia no conjunto de teste
cross_val_bal_3 = cross_val_score(RF(n_estimators=35),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_3)
print(np.mean(cross_val_bal_3))
# Out:
# [ 0.89737991  0.89082969  0.87938596  0.86842105  0.87719298  0.86622807
#   0.89912281  0.87280702  0.9122807   0.89473684]
# 0.885838504558

# %%
# acurácia no conjunto de teste
cross_val_bal_3 = cross_val_score(RF(n_estimators=45),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_3)
print(np.mean(cross_val_bal_3))
# Out:
# [ 0.89082969  0.89519651  0.87280702  0.875       0.88377193  0.88377193
#   0.89912281  0.86403509  0.90570175  0.90789474]
# 0.887813146403

# %%
# acurácia no conjunto de teste
cross_val_bal_3 = cross_val_score(RF(n_estimators=55),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_3)
print(np.mean(cross_val_bal_3))
# Out:
# [ 0.8930131   0.88864629  0.87061404  0.87938596  0.88377193  0.875
#   0.89912281  0.86622807  0.89473684  0.89692982]
# 0.884744886233

# %%
# acurácia no conjunto de treinamento
cross_val_bal_3 = cross_val_score(RF(n_estimators=65),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_3)
print(np.mean(cross_val_bal_3))
# Out:
# [ 0.89737991  0.89519651  0.87719298  0.87938596  0.88377193  0.875
#   0.89254386  0.86622807  0.91008772  0.90789474]
# 0.888468168237

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 3: 0.831
# Acurácia para o conjunto 3: 0.833

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 3: 0.838
# Acurácia para o conjunto 3: 0.839

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 3: 0.838
# Acurácia para o conjunto 3: 0.844

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 3: 0.844
# Acurácia para o conjunto 3: 0.847

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 3: 0.841
# Acurácia para o conjunto 3: 0.841

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=65)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 3: {:.3f}'.format(accuracy_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 3: 0.844
# Acurácia para o conjunto 3: 0.846

# %% [markdown]
# #### F1-Score

# %%
# Busca do melhor hiperparâmetro
validation_graph_f1(model=RF(max_depth=25),X=conjunto3_train,y=conjunto3_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='f1',jobs=-1)

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_3 = cross_val_score(RF(n_estimators=5),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_3)
print(np.mean(cross_val_bal_f1_3))
# Out:
# [ 0.88981289  0.85835095  0.84463895  0.85892116  0.85835095  0.86206897
#   0.88602151  0.84731183  0.875       0.88793103]
# 0.866840823739

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_3 = cross_val_score(RF(n_estimators=10),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_3)
print(np.mean(cross_val_bal_f1_3))
# Out:
# [ 0.90322581  0.88841202  0.87145969  0.87103594  0.88461538  0.87719298
#   0.90322581  0.86695279  0.89912281  0.89732143]
# 0.886256465822

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_3 = cross_val_score(RF(n_estimators=15),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_3)
print(np.mean(cross_val_bal_f1_3))
# Out:
# [ 0.88935282  0.88469602  0.87420043  0.87551867  0.88050314  0.89082969
#   0.88235294  0.86736842  0.89873418  0.89270386]
# 0.883626017486

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_3 = cross_val_score(RF(n_estimators=20),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_3)
print(np.mean(cross_val_bal_f1_3))
# Out:
# [ 0.88235294  0.90322581  0.86652079  0.88565489  0.88222698  0.87878788
#   0.88552916  0.86808511  0.89978678  0.90280778]
# 0.885497810036

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_3 = cross_val_score(RF(n_estimators=25),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_3)
print(np.mean(cross_val_bal_f1_3))
# Out:
# [ 0.87966805  0.89873418  0.8688172   0.88659794  0.89121339  0.87826087
#   0.88469602  0.86993603  0.91561181  0.90752688]
# 0.888106237509

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_3 = cross_val_score(RF(n_estimators=30),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_3)
print(np.mean(cross_val_bal_f1_3))
# Out:
# [ 0.89263158  0.90638298  0.87878788  0.88484848  0.88841202  0.86784141
#   0.90566038  0.86266094  0.90598291  0.89804772]
# 0.889125629806

# %%
# acurácia no conjunto de treinamento
cross_val_bal_f1_3 = cross_val_score(RF(n_estimators=35),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_3)
print(np.mean(cross_val_bal_f1_3))
# Out:
# [ 0.90041494  0.89451477  0.88172043  0.88571429  0.89263158  0.87878788
#   0.89915966  0.8794926   0.90364026  0.90280778]
# 0.891888417587

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.813
# F1-Score para o conjunto 3: 0.625

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=10)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.815
# F1-Score para o conjunto 3: 0.638

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.829
# F1-Score para o conjunto 3: 0.625

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=20)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.829
# F1-Score para o conjunto 3: 0.650

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.832
# F1-Score para o conjunto 3: 0.647

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=30)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.836
# F1-Score para o conjunto 3: 0.653

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.832
# F1-Score para o conjunto 3: 0.645

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=60)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.832
# F1-Score para o conjunto 3: 0.644

# %% [markdown]
# #### ROC AUC

# %%
# Busca do melhor hiperparâmetro
validation_graph_roc(model=RF(max_depth=25),X=conjunto3_train,y=conjunto3_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='roc_auc',jobs=-1)

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_3 = cross_val_score(RF(n_estimators=5),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_3)
print(np.mean(cross_val_bal_roc_3))
# Out:
# [ 0.95763067  0.95389711  0.96227874  0.94986643  0.95561562  0.94302364
#   0.96817635  0.95887297  0.9712931   0.9662235 ]
# 0.958687811484

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_3 = cross_val_score(RF(n_estimators=10),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_3)
print(np.mean(cross_val_bal_roc_3))
# Out:
# [ 0.95763067  0.95389711  0.96227874  0.94986643  0.95561562  0.94302364
#   0.96817635  0.95887297  0.9712931   0.9662235 ]
# 0.958687811484

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_3 = cross_val_score(RF(n_estimators=15),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_3)
print(np.mean(cross_val_bal_roc_3))
# Out:
# [ 0.95763067  0.95389711  0.96227874  0.94986643  0.95561562  0.94302364
#   0.96817635  0.95887297  0.9712931   0.9662235 ]
# 0.958687811484

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_3 = cross_val_score(RF(n_estimators=20),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_3)
print(np.mean(cross_val_bal_roc_3))
# Out:
# [ 0.95763067  0.95389711  0.96227874  0.94986643  0.95561562  0.94302364
#   0.96817635  0.95887297  0.9712931   0.9662235 ]
# 0.958687811484

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_3 = cross_val_score(RF(n_estimators=25),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_3)
print(np.mean(cross_val_bal_roc_3))
# Out:
# [ 0.95763067  0.95389711  0.96227874  0.94986643  0.95561562  0.94302364
#   0.96817635  0.95887297  0.9712931   0.9662235 ]
# 0.958687811484

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_3 = cross_val_score(RF(n_estimators=30),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_3)
print(np.mean(cross_val_bal_roc_3))
# Out:
# [ 0.95763067  0.95389711  0.96227874  0.94986643  0.95561562  0.94302364
#   0.96817635  0.95887297  0.9712931   0.9662235 ]
# 0.958687811484

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_3 = cross_val_score(RF(n_estimators=35),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_3)
print(np.mean(cross_val_bal_roc_3))
# Out:
# [ 0.95763067  0.95389711  0.96227874  0.94986643  0.95561562  0.94302364
#   0.96817635  0.95887297  0.9712931   0.9662235 ]
# 0.958687811484

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_3 = cross_val_score(RF(n_estimators=45),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_3)
print(np.mean(cross_val_bal_roc_3))
# Out:
# [ 0.95763067  0.95389711  0.96227874  0.94986643  0.95561562  0.94302364
#   0.96817635  0.95887297  0.9712931   0.9662235 ]
# 0.958687811484

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_3 = cross_val_score(RF(n_estimators=55),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_3)
print(np.mean(cross_val_bal_roc_3))
# Out:
# [ 0.95763067  0.95389711  0.96227874  0.94986643  0.95561562  0.94302364
#   0.96817635  0.95887297  0.9712931   0.9662235 ]
# 0.958687811484

# %%
# acurácia no conjunto de treinamento
cross_val_bal_roc_3 = cross_val_score(RF(n_estimators=65),conjunto3_train,conjunto3_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_3)
print(np.mean(cross_val_bal_roc_3))
# Out:
# [ 0.95763067  0.95389711  0.96227874  0.94986643  0.95561562  0.94302364
#   0.96817635  0.95887297  0.9712931   0.9662235 ]
# 0.958687811484

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 3: 0.812
# ROC AUC para o conjunto 3: 0.774

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=10)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 3: 0.822
# ROC AUC para o conjunto 3: 0.799

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 3: 0.834
# ROC AUC para o conjunto 3: 0.801

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=20)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 3: 0.833
# ROC AUC para o conjunto 3: 0.798

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 3: 0.844
# ROC AUC para o conjunto 3: 0.809

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=30)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 3: 0.841
# ROC AUC para o conjunto 3: 0.810

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto3_train,conjunto3_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 3: 0.836
# ROC AUC para o conjunto 3: 0.785

# %% [markdown]
# ### Dataset 4

# %%
# Busca do melhor hiperparâmetro
validation_graph_acc(model=RF(max_depth=25),X=conjunto4_train,y=conjunto4_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='accuracy',jobs=-1)

# %%
# acurácia no conjunto de teste
cross_val_bal_4 = cross_val_score(RF(n_estimators=5),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_4)
print(np.mean(cross_val_bal_4))
# Out:
# [ 0.87616822  0.87616822  0.87616822  0.87850467  0.89018692  0.83878505
#   0.85280374  0.87616822  0.88967136  0.85915493]
# 0.871377956211

# %%
# acurácia no conjunto de teste
cross_val_bal_4 = cross_val_score(RF(n_estimators=10),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_4)
print(np.mean(cross_val_bal_4))
# Out:
# [ 0.89485981  0.90654206  0.88551402  0.88084112  0.90186916  0.86915888
#   0.87383178  0.88785047  0.90610329  0.89201878]
# 0.889858935545

# %%
# acurácia no conjunto de teste
cross_val_bal_4 = cross_val_score(RF(n_estimators=15),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_4)
print(np.mean(cross_val_bal_4))
# Out:
# [ 0.89485981  0.89485981  0.87616822  0.89953271  0.90420561  0.87383178
#   0.87850467  0.89018692  0.8943662   0.89201878]
# 0.889853450924

# %%
# acurácia no conjunto de teste
cross_val_bal_4 = cross_val_score(RF(n_estimators=20),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_4)
print(np.mean(cross_val_bal_4))
# Out:
# [ 0.90654206  0.90654206  0.88084112  0.88551402  0.90186916  0.86682243
#   0.87616822  0.90186916  0.90610329  0.88262911]
# 0.891490061867

# %%
# acurácia no conjunto de teste
cross_val_bal_4 = cross_val_score(RF(n_estimators=25),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_4)
print(np.mean(cross_val_bal_4))
# Out:
# [ 0.88551402  0.89953271  0.88785047  0.89719626  0.9228972   0.87616822
#   0.87383178  0.88785047  0.91314554  0.9084507 ]
# 0.895243736563

# %%
# acurácia no conjunto de teste
cross_val_bal_4 = cross_val_score(RF(n_estimators=30),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='accuracy')
print(cross_val_bal_4)
print(np.mean(cross_val_bal_4))
# Out:
# [ 0.89719626  0.89485981  0.89485981  0.88551402  0.90420561  0.88317757
#   0.88551402  0.89252336  0.90610329  0.90610329]
# 0.895005704006

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 4: 0.799
# Acurácia para o conjunto 4: 0.804

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=10)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 4: 0.788
# Acurácia para o conjunto 4: 0.821

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 4: 0.818
# Acurácia para o conjunto 4: 0.822

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=20)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 4: 0.812
# Acurácia para o conjunto 4: 0.824

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 4: 0.806
# Acurácia para o conjunto 4: 0.812

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=30)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 4: 0.811
# Acurácia para o conjunto 4: 0.818

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 4: 0.818
# Acurácia para o conjunto 4: 0.822

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 4: 0.819
# Acurácia para o conjunto 4: 0.826

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 4: 0.816
# Acurácia para o conjunto 4: 0.826

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=65)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('Acurácia para o conjunto 4: {:.3f}'.format(accuracy_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# Acurácia para o conjunto 4: 0.820
# Acurácia para o conjunto 4: 0.827

# %% [markdown]
# #### F1-Score

# %%
# Busca do melhor hiperparâmetro
validation_graph_f1(model=RF(max_depth=25),X=conjunto4_train,y=conjunto4_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='f1',jobs=-1)

# %%
# acurácia no conjunto de teste
cross_val_bal_f1_4 = cross_val_score(RF(n_estimators=5),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_4)
print(np.mean(cross_val_bal_f1_4))
# Out:
# [ 0.8758465   0.88288288  0.89044289  0.85844749  0.89145497  0.88990826
#   0.87272727  0.86621315  0.90950226  0.87471526]
# 0.881214093433

# %%
# acurácia no conjunto de teste
cross_val_bal_f1_4 = cross_val_score(RF(n_estimators=15),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_4)
print(np.mean(cross_val_bal_f1_4))
# Out:
# [ 0.8929385   0.89767442  0.89041096  0.8959276   0.91555556  0.87133183
#   0.88340807  0.89702517  0.90868597  0.89244851]
# 0.894540658468

# %%
# acurácia no conjunto de teste
cross_val_bal_f1_4 = cross_val_score(RF(n_estimators=25),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_4)
print(np.mean(cross_val_bal_f1_4))
# Out:
# [ 0.89244851  0.90574713  0.8951049   0.89390519  0.89686099  0.88340807
#   0.8758465   0.88789238  0.91441441  0.89140271]
# 0.893703079145

# %%
# acurácia no conjunto de teste
cross_val_bal_f1_4 = cross_val_score(RF(n_estimators=35),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_4)
print(np.mean(cross_val_bal_f1_4))
# Out:
# [ 0.90410959  0.90531178  0.8960739   0.89545455  0.91818182  0.89189189
#   0.87133183  0.9009009   0.91759465  0.90497738]
# 0.900582828556

# %%
# acurácia no conjunto de teste
cross_val_bal_f1_4 = cross_val_score(RF(n_estimators=45),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_4)
print(np.mean(cross_val_bal_f1_4))
# Out:
# [ 0.89655172  0.89861751  0.88435374  0.89390519  0.91235955  0.87387387
#   0.89237668  0.89795918  0.91685393  0.90950226]
# 0.897635365378

# %%
# acurácia no conjunto de teste
cross_val_bal_f1_4 = cross_val_score(RF(n_estimators=55),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='f1')
print(cross_val_bal_f1_4)
print(np.mean(cross_val_bal_f1_4))
# Out:
# [ 0.90160183  0.91454965  0.89195402  0.8959276   0.90744921  0.89090909
#   0.88888889  0.91609977  0.91479821  0.89795918]
# 0.902013746197

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.777
# F1-Score para o conjunto 4: 0.587

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.808
# F1-Score para o conjunto 4: 0.637

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.804
# F1-Score para o conjunto 4: 0.620

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.802
# F1-Score para o conjunto 4: 0.615

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.811
# F1-Score para o conjunto 4: 0.626

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.809
# F1-Score para o conjunto 4: 0.637

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=65)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.798
# F1-Score para o conjunto 4: 0.611

# %% [markdown]
# #### ROC AUC

# %%
# Busca do melhor hiperparâmetro
validation_graph_roc(model=RF(max_depth=25),X=conjunto4_train,y=conjunto4_train_target.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='roc_auc',jobs=-1)

# %%
# acurácia no conjunto de teste
cross_val_bal_roc_4 = cross_val_score(RF(n_estimators=5),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_4)
print(np.mean(cross_val_bal_roc_4))
# Out:
# [ 0.94416543  0.93475413  0.94887108  0.91915233  0.95229933  0.93606429
#   0.92997205  0.93678487  0.94432322  0.92808966]
# 0.937447638004

# %%
# acurácia no conjunto de teste
cross_val_bal_roc_4 = cross_val_score(RF(n_estimators=10),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_4)
print(np.mean(cross_val_bal_roc_4))
# Out:
# [ 0.95497423  0.95340204  0.94672024  0.94730981  0.96494235  0.95134946
#   0.952343    0.96069526  0.95054993  0.94907316]
# 0.953135948685

# %%
# acurácia no conjunto de teste
cross_val_bal_roc_4 = cross_val_score(RF(n_estimators=15),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_4)
print(np.mean(cross_val_bal_roc_4))
# Out:
# [ 0.95846799  0.95582584  0.95772557  0.949548    0.96143768  0.95876277
#   0.94949341  0.95447201  0.96444709  0.95680972]
# 0.956699005712

# %%
# acurácia no conjunto de teste
cross_val_bal_roc_4 = cross_val_score(RF(n_estimators=20),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_4)
print(np.mean(cross_val_bal_roc_4))
# Out:
# [ 0.95118569  0.96014936  0.95986549  0.95550921  0.9690366   0.9553782
#   0.95371867  0.95855533  0.96319072  0.95716238]
# 0.958375165463

# %%
# acurácia no conjunto de teste
cross_val_bal_roc_4 = cross_val_score(RF(n_estimators=25),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_4)
print(np.mean(cross_val_bal_roc_4))
# Out:
# [ 0.95629531  0.95992008  0.96058608  0.94990829  0.96998646  0.95505066
#   0.9539807   0.9596908   0.96334502  0.95661134]
# 0.958537473502

# %%
# acurácia no conjunto de teste
cross_val_bal_roc_4 = cross_val_score(RF(n_estimators=35),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_4)
print(np.mean(cross_val_bal_roc_4))
# Out:
# [ 0.95725609  0.9621146   0.96206001  0.95826055  0.96887283  0.95482138
#   0.95654642  0.96210368  0.96141639  0.96531773]
# 0.960876966256

# %%
# acurácia no conjunto de teste
cross_val_bal_roc_4 = cross_val_score(RF(n_estimators=45),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_4)
print(np.mean(cross_val_bal_roc_4))
# Out:
# [ 0.96037864  0.96001834  0.96390514  0.96036772  0.96935322  0.96235479
#   0.95685213  0.96190715  0.96422667  0.96176905]
# 0.962113285383

# %%
# acurácia no conjunto de teste
cross_val_bal_roc_4 = cross_val_score(RF(n_estimators=55),conjunto4_train,conjunto4_train_target.earnings,cv=10,scoring='roc_auc')
print(cross_val_bal_roc_4)
print(np.mean(cross_val_bal_roc_4))
# Out:
# [ 0.96349026  0.96341384  0.96429819  0.96014936  0.96844703  0.96126299
#   0.95489781  0.95951611  0.96396218  0.96568141]
# 0.962511917662

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.793
# ROC AUC para o conjunto 4: 0.764

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.820
# ROC AUC para o conjunto 4: 0.778

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.822
# ROC AUC para o conjunto 4: 0.781

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.818
# ROC AUC para o conjunto 4: 0.779

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.813
# ROC AUC para o conjunto 4: 0.775

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.815
# ROC AUC para o conjunto 4: 0.769

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=65)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.810
# ROC AUC para o conjunto 4: 0.770

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=75)
clf_rf.fit(conjunto4_train,conjunto4_train_target.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.815
# ROC AUC para o conjunto 4: 0.770

# %% [markdown]
# ### Avaliação dos modelos para cada cenário

# %%
modelos_balanceados = [cross_val_bal_1, cross_val_bal_2, cross_val_bal_3, cross_val_bal_4]
labels = ['n = 20, Dataset 1', 'n = 25, Dataset 2', 'n = 55, Dataset 3', 'n= 40, Dataset 4']
plt.figure(figsize=(25,10))
sns.boxplot(data=modelos_balanceados)
plt.xticks(list(range(0,4)),labels,fontsize=15)
plt.yticks(fontsize=15)
plt.title('Max_depth = 25',fontsize=15)
plt.ylabel('Acurácia',fontsize=15)
plt.show()

# %% [markdown]
# Falar sobre acurácia e outliers!!! Com outliers, pontos distantes são difíceis de predizer, assim o método 3 foi bom! Escrever mais depois sobre...

# %% [markdown]
# ### Cenários para os datasets desbalanceado

# %%
# Teste base: Verificando o funcionamento correto do modelo para as configurações padrões: K = 5
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)
prediction_conjunto1 = clf_rf.predict(conjunto1_test_desbalanceado)
print('F1 para o conjunto 1: {:.2f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_conjunto1)))
print('ROC AUC para o conjunto 1: {:.2f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_conjunto1)))
print()

clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)
prediction_conjunto2 = clf_rf.predict(conjunto2_test_desbalanceado)
print('F1 para o conjunto 2: {:.2f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_conjunto2)))
print('ROC AUC para o conjunto 2: {:.2f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_conjunto2)))
print()

clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)
prediction_conjunto3 = clf_rf.predict(conjunto3_test_desbalanceado)
print('F1 para o conjunto 3: {:.2f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_conjunto3)))
print('ROC AUC para o conjunto 3: {:.2f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_conjunto3)))
print()

clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)
prediction_conjunto4 = clf_rf.predict(conjunto4_test_desbalanceado)
print('F1 para o conjunto 4: {:.2f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_conjunto4)))
print('ROC AUC para o conjunto 4: {:.2f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_conjunto4)))
# Out:
# F1 para o conjunto 1: 0.67
# ROC AUC para o conjunto 1: 0.77
#
# F1 para o conjunto 2: 0.65
# ROC AUC para o conjunto 2: 0.76
#
# F1 para o conjunto 3: 0.67
# ROC AUC para o conjunto 3: 0.79
#
# F1 para o conjunto 4: 0.61
# ROC AUC para o conjunto 4: 0.74

# %% [markdown]
# ### Dataset 1

# %% [markdown]
# #### F1-Score

# %%
validation_graph_f1(model=RF(max_depth=25),X=conjunto1_train_desbalanceado,y=conjunto1_train_target_desbalanceado.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='f1',jobs=-1)

# %%
cross_val_desbal_f1_1 = cross_val_score(RF(n_estimators=15),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_1)
print(np.mean(cross_val_desbal_f1_1))
# Out:
# [ 0.65079365  0.56716418  0.58208955  0.64179104  0.5         0.70588235
#   0.67669173  0.72340426  0.57364341  0.62015504]
# 0.624161521411

# %%
cross_val_desbal_f1_1 = cross_val_score(RF(n_estimators=25),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_1)
print(np.mean(cross_val_desbal_f1_1))
# Out:
# [ 0.54545455  0.61654135  0.58267717  0.60606061  0.6446281   0.69117647
#   0.67142857  0.70588235  0.65217391  0.61904762]
# 0.633507069648

# %%
cross_val_desbal_f1_1 = cross_val_score(RF(n_estimators=35),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_1)
print(np.mean(cross_val_desbal_f1_1))
# Out:
# [ 0.63414634  0.60992908  0.546875    0.61068702  0.56198347  0.67153285
#   0.70072993  0.74074074  0.65693431  0.62992126]
# 0.636347999433

# %%
cross_val_desbal_f1_1 = cross_val_score(RF(n_estimators=45),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_1)
print(np.mean(cross_val_desbal_f1_1))
# Out:
# [ 0.63076923  0.61654135  0.53125     0.61068702  0.576       0.69230769
#   0.69064748  0.73529412  0.6         0.61538462]
# 0.629888151441

# %%
cross_val_desbal_f1_1 = cross_val_score(RF(n_estimators=55),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_1)
print(np.mean(cross_val_desbal_f1_1))
# Out:
# [ 0.62295082  0.58333333  0.58730159  0.62015504  0.578125    0.6870229
#   0.66666667  0.72058824  0.61654135  0.61068702]
# 0.629337195808

# %%
cross_val_desbal_f1_1 = cross_val_score(RF(n_estimators=65),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_1)
print(np.mean(cross_val_desbal_f1_1))
# Out:
# [ 0.6504065   0.62773723  0.58914729  0.59541985  0.609375    0.66666667
#   0.65185185  0.67175573  0.66176471  0.65116279]
# 0.637528760478

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.758
# F1-Score para o conjunto 1: 0.763

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.767
# F1-Score para o conjunto 1: 0.771

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.769
# F1-Score para o conjunto 1: 0.766

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.777
# F1-Score para o conjunto 1: 0.779

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.766
# F1-Score para o conjunto 1: 0.771

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.758
# F1-Score para o conjunto 1: 0.763

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.758
# F1-Score para o conjunto 1: 0.763

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.758
# F1-Score para o conjunto 1: 0.763

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.758
# F1-Score para o conjunto 1: 0.763

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.758
# F1-Score para o conjunto 1: 0.763

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.758
# F1-Score para o conjunto 1: 0.763

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=65)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 1: {:.3f}'.format(f1_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 1: 0.758
# F1-Score para o conjunto 1: 0.763

# %% [markdown]
# #### ROC-AUC

# %%
validation_graph_roc(model=RF(max_depth=25),X=conjunto1_train_desbalanceado,y=conjunto1_train_target_desbalanceado.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='roc_auc',jobs=-1)

# %%
cross_val_desbal_roc_1 = cross_val_score(RF(n_estimators=5),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_1)
print(np.mean(cross_val_desbal_roc_1))
# Out:
# [ 0.84388528  0.82943113  0.75641729  0.81720627  0.82571185  0.86436803
#   0.83769282  0.88079995  0.84254009  0.79888421]
# 0.829693692458

# %%
cross_val_desbal_roc_1 = cross_val_score(RF(n_estimators=15),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_1)
print(np.mean(cross_val_desbal_roc_1))
# Out:
# [ 0.88449976  0.86171575  0.83138223  0.88631791  0.86942869  0.90930431
#   0.86110603  0.9195171   0.89098226  0.87058716]
# 0.878484120209

# %%
cross_val_desbal_roc_1 = cross_val_score(RF(n_estimators=25),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_1)
print(np.mean(cross_val_desbal_roc_1))
# Out:
# [ 0.89592352  0.84766173  0.830803    0.88604353  0.88845192  0.91942564
#   0.86921529  0.92122432  0.9073837   0.88104384]
# 0.88471764933

# %%
cross_val_desbal_roc_1 = cross_val_score(RF(n_estimators=35),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_1)
print(np.mean(cross_val_desbal_roc_1))
# Out:
# [ 0.89490139  0.86857509  0.83217487  0.9039083   0.84830193  0.9151881
#   0.86720322  0.91979148  0.89573806  0.89973172]
# 0.884551416242

# %%
cross_val_desbal_roc_1 = cross_val_score(RF(n_estimators=45),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_1)
print(np.mean(cross_val_desbal_roc_1))
# Out:
# [ 0.89718615  0.86583135  0.83985733  0.87845253  0.87616609  0.93201634
#   0.86689836  0.91997439  0.90723127  0.8869886 ]
# 0.887060240229

# %%
cross_val_desbal_roc_1 = cross_val_score(RF(n_estimators=55),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_1)
print(np.mean(cross_val_desbal_roc_1))
# Out:
# [ 0.90806878  0.86430705  0.84040607  0.891531    0.87421499  0.92881532
#   0.86180721  0.92396805  0.90695689  0.88208036]
# 0.888215572899

# %%
cross_val_desbal_roc_1 = cross_val_score(RF(n_estimators=65),conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_1)
print(np.mean(cross_val_desbal_roc_1))
# Out:
# [ 0.89472102  0.8681178   0.84632035  0.88659228  0.8811353   0.91726114
#   0.86726419  0.92000488  0.91271874  0.88256814]
# 0.887670382565

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 1: 0.762
# ROC AUC para o conjunto 1: 0.761

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 1: 0.766
# ROC AUC para o conjunto 1: 0.758

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 1: 0.763
# ROC AUC para o conjunto 1: 0.768

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 1: 0.774
# ROC AUC para o conjunto 1: 0.775

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 1: 0.758
# ROC AUC para o conjunto 1: 0.767

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto1_train_desbalanceado,conjunto1_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto1_test)
prediction_desbalanceado = clf_rf.predict(conjunto1_test_desbalanceado)

print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 1: {:.3f}'.format(roc_auc_score(conjunto1_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 1: 0.774
# ROC AUC para o conjunto 1: 0.780

# %% [markdown]
# ### Dataset 2

# %% [markdown]
# #### F1-Score

# %%
validation_graph_f1(model=RF(max_depth=8),X=conjunto2_train_desbalanceado,y=conjunto2_train_target_desbalanceado.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='f1',jobs=-1)

# %%
cross_val_desbal_f1_2 = cross_val_score(RF(n_estimators=5),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_2)
print(np.mean(cross_val_desbal_f1_2))
# Out:
# [0.5942029  0.61654135 0.59541985 0.66165414 0.65693431 0.55223881
#  0.65217391 0.63768116 0.56716418 0.59574468]
# 0.6129755279559574

# %%
cross_val_desbal_f1_2 = cross_val_score(RF(n_estimators=15),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_2)
print(np.mean(cross_val_desbal_f1_2))
# Out:
# [0.60992908 0.6618705  0.61538462 0.70503597 0.63157895 0.68613139
#  0.64788732 0.65277778 0.57971014 0.58992806]
# 0.6380233806651611

# %%
cross_val_desbal_f1_2 = cross_val_score(RF(n_estimators=25),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_2)
print(np.mean(cross_val_desbal_f1_2))
# Out:
# [0.62773723 0.60869565 0.624      0.73381295 0.640625   0.6870229
#  0.69863014 0.64705882 0.57777778 0.62857143]
# 0.6473931895719851

# %%
cross_val_desbal_f1_2 = cross_val_score(RF(n_estimators=35),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_2)
print(np.mean(cross_val_desbal_f1_2))
# Out:
# [0.58571429 0.68027211 0.63414634 0.73134328 0.62992126 0.63636364
#  0.69014085 0.67164179 0.58461538 0.61764706]
# 0.6461805995363596

# %%
cross_val_desbal_f1_2 = cross_val_score(RF(n_estimators=45),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_2)
print(np.mean(cross_val_desbal_f1_2))
# Out:
# [0.57971014 0.68613139 0.60504202 0.75714286 0.64566929 0.67164179
#  0.69503546 0.67153285 0.53125    0.67153285]
# 0.6514688642545353

# %%
cross_val_desbal_f1_2 = cross_val_score(RF(n_estimators=55),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_2)
print(np.mean(cross_val_desbal_f1_2))
# Out:
# [0.5915493  0.66176471 0.6446281  0.77037037 0.609375   0.69064748
#  0.69387755 0.68148148 0.59090909 0.6618705 ]
# 0.6596473580223416

# %%
cross_val_desbal_f1_2 = cross_val_score(RF(n_estimators=65),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_2)
print(np.mean(cross_val_desbal_f1_2))
# Out:
# [0.61428571 0.70422535 0.63333333 0.73381295 0.60465116 0.68148148
#  0.68531469 0.65671642 0.5648855  0.63888889]
# 0.6517595481941418

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.668
# F1-Score para o conjunto 2: 0.635

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=10)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.639
# F1-Score para o conjunto 2: 0.635

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.673
# F1-Score para o conjunto 2: 0.650

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.676
# F1-Score para o conjunto 2: 0.660

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.665
# F1-Score para o conjunto 2: 0.648

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.675
# F1-Score para o conjunto 2: 0.648

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto2_test)
prediction_desbalanceado = clf_rf.predict(conjunto2_test_desbalanceado)

print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 2: {:.3f}'.format(f1_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 2: 0.664
# F1-Score para o conjunto 2: 0.645

# %% [markdown]
# #### ROC-AUC

# %%
validation_graph_roc(model=RF(max_depth=8),X=conjunto2_train_desbalanceado,y=conjunto2_train_target_desbalanceado.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='roc_auc',jobs=-1)

# %%
cross_val_desbal_roc_2 = cross_val_score(RF(n_estimators=5),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_2)
print(np.mean(cross_val_desbal_roc_2))
# Out:
# [0.83107612 0.86817648 0.81791475 0.87370473 0.86013781 0.87797778
#  0.8804882  0.87586796 0.79473347 0.83273689]
# 0.851281417765841

# %%
cross_val_desbal_roc_2 = cross_val_score(RF(n_estimators=15),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_2)
print(np.mean(cross_val_desbal_roc_2))
# Out:
# [0.85839895 0.88484136 0.8588826  0.90030445 0.87509347 0.89904925
#  0.90481786 0.8919453  0.85065698 0.84125628]
# 0.8765246509152707

# %%
cross_val_desbal_roc_2 = cross_val_score(RF(n_estimators=25),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_2)
print(np.mean(cross_val_desbal_roc_2))
# Out:
# [0.88152231 0.88665741 0.89285333 0.92020083 0.88238436 0.89536374
#  0.91400491 0.89648542 0.870313   0.85861553]
# 0.8898400848328956

# %%
cross_val_desbal_roc_2 = cross_val_score(RF(n_estimators=35),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_2)
print(np.mean(cross_val_desbal_roc_2))
# Out:
# [0.87020997 0.90716804 0.87386497 0.92906741 0.90139942 0.91531353
#  0.90545882 0.90473774 0.86756223 0.84323256]
# 0.8918014695471046

# %%
cross_val_desbal_roc_2 = cross_val_score(RF(n_estimators=45),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_2)
print(np.mean(cross_val_desbal_roc_2))
# Out:
# [0.87488189 0.90003739 0.87447922 0.91873197 0.8972065  0.90102553
#  0.90289499 0.90139942 0.86761564 0.8568529 ]
# 0.8895125453485603

# %%
cross_val_desbal_roc_2 = cross_val_score(RF(n_estimators=55),conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_2)
print(np.mean(cross_val_desbal_roc_2))
# Out:
# [0.87524934 0.89052986 0.88724495 0.93032262 0.89616494 0.91905245
#  0.9062066  0.90666061 0.86852366 0.85468967]
# 0.8934644707575211

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.836
# ROC AUC para o conjunto 2: 0.844

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.865
# ROC AUC para o conjunto 2: 0.873

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.877
# ROC AUC para o conjunto 2: 0.883

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.882
# ROC AUC para o conjunto 2: 0.886

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.886
# ROC AUC para o conjunto 2: 0.893

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict_proba(conjunto2_test)[:,1]
prediction_desbalanceado = clf_rf.predict_proba(conjunto2_test_desbalanceado)[:,1]

print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 2: {:.3f}'.format(roc_auc_score(conjunto2_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 2: 0.885
# ROC AUC para o conjunto 2: 0.890

# %%
path_arquivos = 'Classificadores/Random-forest/'

clf_rf = RF(n_estimators=20, max_depth=8)
clf_rf.fit(conjunto2_train_desbalanceado,conjunto2_train_target_desbalanceado.earnings)
joblib.dump(clf_rf, 
            path_arquivos+'rf-final-abordagem-2-desbalanceado-dataset-'+str(int(fracao_dataset*100))+'pct.pkl')

path_arquivos = 'Classificadores/Random-forest/'

clf_final_desbalanceado = joblib.load(path_arquivos+'rf-final-abordagem-2-desbalanceado-dataset-'+str(int(fracao_dataset*100))+'pct.pkl')

exibir_resultados_finais(clf=clf_final_desbalanceado, 
                         test_data=conjunto2_test_desbalanceado, 
                         test_target=conjunto2_test_target_desbalanceado.earnings, 
                         id_abordagem=2, 
                         str_balanceamento='desbalanceado', 
                         fracao_dataset=0.1,
                         path_arquivos=path_arquivos,
                         tipo_classificador='rf',
                         salvar_resultados=True)
# Out:
# Acurácia: 84.801 %
# Precisão: 78.715 %
# Recall: 50.515 %
# F1 score: 61.538462 %
# ROC AUC: 90.386 %
# PRC AUC: 76.976 %

# %% [markdown]
# ### Dataset 3

# %% [markdown]
# #### F1-Score

# %%
# Busca do melhor hiperparâmetro
validation_graph_f1(model=RF(max_depth=25),X=conjunto3_train_desbalanceado,y=conjunto3_train_target_desbalanceado.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='f1',jobs=-1)

# %%
# acurácia no conjunto de teste
cross_val_desbal_f1_3 = cross_val_score(RF(n_estimators=15),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_3)
print(np.mean(cross_val_desbal_f1_3))
# Out:
# [ 0.55737705  0.62222222  0.57142857  0.62295082  0.6779661   0.52173913
#   0.66666667  0.72727273  0.52        0.45833333]
# 0.594595662191

# %%
# acurácia no conjunto de teste
cross_val_desbal_f1_3 = cross_val_score(RF(n_estimators=25),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_3)
print(np.mean(cross_val_desbal_f1_3))
# Out:
# [ 0.55737705  0.62222222  0.57142857  0.62295082  0.6779661   0.52173913
#   0.66666667  0.72727273  0.52        0.45833333]
# 0.594595662191

# %%
# acurácia no conjunto de teste
cross_val_desbal_f1_3 = cross_val_score(RF(n_estimators=35),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_3)
print(np.mean(cross_val_desbal_f1_3))
# Out:
# [ 0.55737705  0.62222222  0.57142857  0.62295082  0.6779661   0.52173913
#   0.66666667  0.72727273  0.52        0.45833333]
# 0.594595662191

# %%
# acurácia no conjunto de teste
cross_val_desbal_f1_3 = cross_val_score(RF(n_estimators=45),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_3)
print(np.mean(cross_val_desbal_f1_3))
# Out:
# [ 0.55737705  0.62222222  0.57142857  0.62295082  0.6779661   0.52173913
#   0.66666667  0.72727273  0.52        0.45833333]
# 0.594595662191

# %%
# acurácia no conjunto de teste
cross_val_desbal_f1_3 = cross_val_score(RF(n_estimators=55),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_3)
print(np.mean(cross_val_desbal_f1_3))
# Out:
# [ 0.55737705  0.62222222  0.57142857  0.62295082  0.6779661   0.52173913
#   0.66666667  0.72727273  0.52        0.45833333]
# 0.594595662191

# %%
# acurácia no conjunto de teste
cross_val_desbal_f1_3 = cross_val_score(RF(n_estimators=65),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_3)
print(np.mean(cross_val_desbal_f1_3))
# Out:
# [ 0.55737705  0.62222222  0.57142857  0.62295082  0.6779661   0.52173913
#   0.66666667  0.72727273  0.52        0.45833333]
# 0.594595662191

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.699
# F1-Score para o conjunto 3: 0.619

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.753
# F1-Score para o conjunto 3: 0.671

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.746
# F1-Score para o conjunto 3: 0.667

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.723
# F1-Score para o conjunto 3: 0.667

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.724
# F1-Score para o conjunto 3: 0.667

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.724
# F1-Score para o conjunto 3: 0.659

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=65)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 3: {:.3f}'.format(f1_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 3: 0.737
# F1-Score para o conjunto 3: 0.670

# %% [markdown]
# #### ROC-AUC

# %%
validation_graph_roc(model=RF(max_depth=25),X=conjunto3_train_desbalanceado,y=conjunto3_train_target_desbalanceado.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='roc_auc',jobs=-1)

# %%
cross_val_desbal_roc_3 = cross_val_score(RF(n_estimators=5),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_3)
print(np.mean(cross_val_desbal_roc_3))
# Out:
# [ 0.82708727  0.8567099   0.83369883  0.83153907  0.85935008  0.85376794
#   0.84449761  0.8419059   0.77033493  0.82582403]
# 0.834471556582

# %%
cross_val_desbal_roc_3 = cross_val_score(RF(n_estimators=15),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_3)
print(np.mean(cross_val_desbal_roc_3))
# Out:
# [ 0.87821808  0.8693541   0.85619351  0.88161217  0.87523259  0.86732456
#   0.85928363  0.87862174  0.8373538   0.84177299]
# 0.864496718541

# %%
cross_val_desbal_roc_3 = cross_val_score(RF(n_estimators=25),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_3)
print(np.mean(cross_val_desbal_roc_3))
# Out:
# [ 0.89223098  0.88616959  0.86881978  0.8767278   0.89789341  0.87666135
#   0.87343833  0.89709596  0.84270335  0.85931685]
# 0.877105740502

# %%
cross_val_desbal_roc_3 = cross_val_score(RF(n_estimators=35),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_3)
print(np.mean(cross_val_desbal_roc_3))
# Out:
# [ 0.8831063   0.87590432  0.86802233  0.87828947  0.88809144  0.89300904
#   0.87333865  0.89490298  0.85479798  0.8662613 ]
# 0.877572380821

# %%
cross_val_desbal_roc_3 = cross_val_score(RF(n_estimators=45),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_3)
print(np.mean(cross_val_desbal_roc_3))
# Out:
# [ 0.88952617  0.87697973  0.86450027  0.88330675  0.88473551  0.88257576
#   0.88530037  0.89556752  0.84419856  0.86111111]
# 0.876780175172

# %%
cross_val_desbal_roc_3 = cross_val_score(RF(n_estimators=55),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_3)
print(np.mean(cross_val_desbal_roc_3))
# Out:
# [ 0.88590888  0.88555041  0.86955077  0.89251063  0.89380649  0.88520069
#   0.87878788  0.89510234  0.8419059   0.85948299]
# 0.87878069848

# %%
cross_val_desbal_roc_3 = cross_val_score(RF(n_estimators=65),conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_3)
print(np.mean(cross_val_desbal_roc_3))
# Out:
# [ 0.88499642  0.87909796  0.87330542  0.88586523  0.90038543  0.88746013
#   0.87373737  0.89633174  0.83117358  0.86287214]
# 0.87752254226

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.671
# ROC AUC para o conjunto 4: 0.556

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.671
# ROC AUC para o conjunto 4: 0.556

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.671
# ROC AUC para o conjunto 4: 0.556

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.671
# ROC AUC para o conjunto 4: 0.556

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.671
# ROC AUC para o conjunto 4: 0.556

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.671
# ROC AUC para o conjunto 4: 0.556

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=65)
clf_rf.fit(conjunto3_train_desbalanceado,conjunto3_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto3_test)
prediction_desbalanceado = clf_rf.predict(conjunto3_test_desbalanceado)

print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 3: {:.3f}'.format(roc_auc_score(conjunto3_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.671
# ROC AUC para o conjunto 4: 0.556

# %% [markdown]
# ### Dataset 4

# %% [markdown]
# #### F1-Score

# %%
validation_graph_f1(model=RF(max_depth=25),X=conjunto4_train_desbalanceado,y=conjunto4_train_target_desbalanceado.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='f1',jobs=-1)

# %%
cross_val_desbal_f1_4 = cross_val_score(RF(n_estimators=5),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_4)
print(np.mean(cross_val_desbal_f1_4))
# Out:
# [ 0.56198347  0.60176991  0.63793103  0.5840708   0.61157025  0.65546218
#   0.5982906   0.66666667  0.66141732  0.63934426]
# 0.621850649642

# %%
cross_val_desbal_f1_4 = cross_val_score(RF(n_estimators=15),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_4)
print(np.mean(cross_val_desbal_f1_4))
# Out:
# [ 0.65079365  0.57627119  0.57142857  0.61682243  0.66115702  0.7107438
#   0.63247863  0.69491525  0.63414634  0.67768595]
# 0.642644284361

# %%
cross_val_desbal_f1_4 = cross_val_score(RF(n_estimators=25),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_4)
print(np.mean(cross_val_desbal_f1_4))
# Out:
# [ 0.62184874  0.54545455  0.58252427  0.64220183  0.67226891  0.65546218
#   0.6440678   0.73333333  0.63414634  0.66666667]
# 0.639797462217

# %%
cross_val_desbal_f1_4 = cross_val_score(RF(n_estimators=35),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_4)
print(np.mean(cross_val_desbal_f1_4))
# Out:
# [ 0.672       0.51376147  0.59615385  0.66666667  0.75806452  0.66101695
#   0.64912281  0.71666667  0.66666667  0.69354839]
# 0.659366797344

# %%
cross_val_desbal_f1_4 = cross_val_score(RF(n_estimators=45),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_4)
print(np.mean(cross_val_desbal_f1_4))
# Out:
# [ 0.65        0.4952381   0.59047619  0.64220183  0.7107438   0.65546218
#   0.64957265  0.72881356  0.66666667  0.65546218]
# 0.644463716754

# %%
cross_val_desbal_f1_4 = cross_val_score(RF(n_estimators=55),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_4)
print(np.mean(cross_val_desbal_f1_4))
# Out:
# [ 0.66141732  0.57657658  0.60194175  0.61261261  0.7394958   0.65546218
#   0.61261261  0.69354839  0.6440678   0.72131148]
# 0.651904651452

# %%
cross_val_desbal_f1_4 = cross_val_score(RF(n_estimators=65),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='f1')
print(cross_val_desbal_f1_4)
print(np.mean(cross_val_desbal_f1_4))
# Out:
# [ 0.6446281   0.5840708   0.60784314  0.64220183  0.71186441  0.66086957
#   0.61403509  0.73770492  0.66101695  0.69421488]
# 0.655844967069

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.681
# F1-Score para o conjunto 4: 0.585

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.707
# F1-Score para o conjunto 4: 0.610

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.696
# F1-Score para o conjunto 4: 0.596

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.693
# F1-Score para o conjunto 4: 0.603

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.710
# F1-Score para o conjunto 4: 0.632

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.699
# F1-Score para o conjunto 4: 0.613

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('F1-Score para o conjunto 4: {:.3f}'.format(f1_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# F1-Score para o conjunto 4: 0.648
# F1-Score para o conjunto 4: 0.565

# %% [markdown]
# #### ROC-AUC

# %%
validation_graph_roc(model=RF(max_depth=25),X=conjunto4_train_desbalanceado,y=conjunto4_train_target_desbalanceado.earnings,hyperparameter='n_estimators',
                 grid_search=list(range(5,100,5)),k_folds=10,score='roc_auc',jobs=-1)

# %%
cross_val_desbal_roc_4 = cross_val_score(RF(n_estimators=5),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_4)
print(np.mean(cross_val_desbal_roc_4))
# Out:
# [ 0.86061876  0.88785047  0.87383178  0.83854335  0.85417338  0.90331937
#   0.83580406  0.86368031  0.79407025  0.90960361]
# 0.86214953271

# %%
cross_val_desbal_roc_4 = cross_val_score(RF(n_estimators=15),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_4)
print(np.mean(cross_val_desbal_roc_4))
# Out:
# [ 0.86061876  0.88785047  0.87383178  0.83854335  0.85417338  0.90331937
#   0.83580406  0.86368031  0.79407025  0.90960361]
# 0.86214953271

# %%
cross_val_desbal_roc_4 = cross_val_score(RF(n_estimators=25),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_4)
print(np.mean(cross_val_desbal_roc_4))
# Out:
# [ 0.86061876  0.88785047  0.87383178  0.83854335  0.85417338  0.90331937
#   0.83580406  0.86368031  0.79407025  0.90960361]
# 0.86214953271

# %%
cross_val_desbal_roc_4 = cross_val_score(RF(n_estimators=35),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_4)
print(np.mean(cross_val_desbal_roc_4))
# Out:
# [ 0.86061876  0.88785047  0.87383178  0.83854335  0.85417338  0.90331937
#   0.83580406  0.86368031  0.79407025  0.90960361]
# 0.86214953271

# %%
cross_val_desbal_roc_4 = cross_val_score(RF(n_estimators=45),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_4)
print(np.mean(cross_val_desbal_roc_4))
# Out:
# [ 0.86061876  0.88785047  0.87383178  0.83854335  0.85417338  0.90331937
#   0.83580406  0.86368031  0.79407025  0.90960361]
# 0.86214953271

# %%
cross_val_desbal_roc_4 = cross_val_score(RF(n_estimators=55),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_4)
print(np.mean(cross_val_desbal_roc_4))
# Out:
# [ 0.86061876  0.88785047  0.87383178  0.83854335  0.85417338  0.90331937
#   0.83580406  0.86368031  0.79407025  0.90960361]
# 0.86214953271

# %%
cross_val_desbal_roc_4 = cross_val_score(RF(n_estimators=65),conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings,cv=10,scoring='roc_auc')
print(cross_val_desbal_roc_4)
print(np.mean(cross_val_desbal_roc_4))
# Out:
# [ 0.86061876  0.88785047  0.87383178  0.83854335  0.85417338  0.90331937
#   0.83580406  0.86368031  0.79407025  0.90960361]
# 0.86214953271

# %% [markdown]
# #### Performance

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=5)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.736
# ROC AUC para o conjunto 4: 0.722

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=15)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.729
# ROC AUC para o conjunto 4: 0.731

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=25)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.743
# ROC AUC para o conjunto 4: 0.746

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=35)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.754
# ROC AUC para o conjunto 4: 0.752

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=45)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.751
# ROC AUC para o conjunto 4: 0.749

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=55)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.754
# ROC AUC para o conjunto 4: 0.754

# %%
# Desempenho no conjunto de teste - conjunto balanceado
clf_rf = RF(n_estimators=65)
clf_rf.fit(conjunto4_train_desbalanceado,conjunto4_train_target_desbalanceado.earnings)

prediction_balanceado    = clf_rf.predict(conjunto4_test)
prediction_desbalanceado = clf_rf.predict(conjunto4_test_desbalanceado)

print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target.earnings,prediction_balanceado)))
print('ROC AUC para o conjunto 4: {:.3f}'.format(roc_auc_score(conjunto4_test_target_desbalanceado.earnings,prediction_desbalanceado)))
# Out:
# ROC AUC para o conjunto 4: 0.756
# ROC AUC para o conjunto 4: 0.761

# %% [markdown]
# ### Avaliação dos modelos para cada cenário

# %%
modelos_desbalanceados = [cross_val_desbal_f1_1, cross_val_desbal_f1_2, cross_val_desbal_f1_3, cross_val_desbal_f1_4]
labels = ['RF = , Dataset 1', 'RF = , Dataset 2', 'RF = , Dataset 3', 'RF = , Dataset 4']
plt.figure(figsize=(25,10))
sns.boxplot(data=modelos_desbalanceados)
plt.xticks(list(range(0,4)),labels,fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('F1-Score')
plt.show()

# %%
modelos_desbalanceados = [cross_val_desbal_roc_1, cross_val_desbal_roc_2, cross_val_desbal_roc_3, cross_val_desbal_roc_4]
labels = ['RF = , Dataset 1', 'RF = , Dataset 2', 'RF = , Dataset 3', 'RF = , Dataset 4']
plt.figure(figsize=(25,10))
sns.boxplot(data=modelos_desbalanceados)
plt.xticks(list(range(0,4)),labels,fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('F1-Score')
plt.show()
